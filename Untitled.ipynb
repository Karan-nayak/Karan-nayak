# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\yani\Downloads\restaurantsomosa.csv")
df.head()
# Out:
#   Serial Number    Receipt Number              Date  Register Name Draft Name  \
# 0        SA6209  SA-Q2I-2007-6212  01-11-2021 11:03  Main Register    Table 4
# 1        SA6209  SA-Q2I-2007-6212  01-11-2021 11:03            NaN        NaN
# 2        SA6209  SA-Q2I-2007-6212  01-11-2021 11:03            NaN        NaN
# 3        SA6211  SA-Q2I-2007-6213  01-11-2021 12:21  Main Register    Table 2
# 4        SA6211  SA-Q2I-2007-6213  01-11-2021 12:21            NaN        NaN
#
#    Occupants  Total Product Count            Product Name   Product Category  \
# 0        NaN                  3.0               Veg Maggi  Maggi Maggi Maggi
# 1        NaN                  NaN     Cold Drink - Sprite             Unchai
# 2        NaN                  NaN      Adrak Elaichi Chai               Chai
# 3        NaN                  3.0  Tandoori Cheese Burger            Burgers
# 4        NaN                  NaN            Butter Maggi  Maggi Maggi Maggi
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5684 entries, 0 to 5683
# Data columns (total 47 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Serial Number        5684 non-null   object
#  1   Receipt Number       5684 non-null   object
#  2   Date                 5684 non-null   object
#  3   Register Name        2167 non-null   object
#  4   Draft Name           2167 non-null   object
#  5   Occupants            0 non-null      float64
#  6   Total Product Count  2167 non-null   float64
#  7   Product Name         5670 non-null   object
#  8   Product Category     5670 non-null   object
#  9   Product Notes        0 non-null      float64
#  10  Product Quantity     5670 non-null   float64
#  11  Product Price        5417 non-null   float64
#  12  Product Tax          5417 non-null   float64
#  13  Product Zero Tax     5417 non-null   float64
#  14  Product Discount     5417 non-null   float64
# ...

# %%
df['Product Name'].isna().sum()
# Out:
# 14

# %%
df['Product Name'].dropna(inplace=True)

# %%
common_match = df.groupby('Serial Number')['Product Name'].unique().astype(str).value_counts()
common_match[:10]
# Out:
# ['Adrak Chai']                           100
# ['Classic Hot Coffee']                    41
# ['Elaichi Chai']                          33
# ['Adrak Elaichi Chai']                    29
# ['Butter Maggi']                          28
# ['Adrak Chai' 'Kulhad / Clay Pot']        25
# ['Water (500 ml)']                        17
# ['White Sauce / Alfredo Penne Pasta']     16
# [nan]                                     14
# ['Adrak Chai' 'Aloo Samosa (2Pcs)']       13
# Name: Product Name, dtype: int64

# %%
df1 = df.reset_index()
df1 = df1.merge(df1, on='Serial Number').query('index_x > index_y')

df1 = pd.DataFrame(np.sort(df1[['Product Name_x', 'Product Name_y']].to_numpy(), axis = 1))
df1.groupby([*df1]).size().sort_values(ascending=False)
# Out:
# 0                         1
# Adrak Chai                Kulhad / Clay Pot                                  130
#                           Elaichi Chai                                        66
# Elaichi Chai              Kulhad / Clay Pot                                   57
# Adrak Chai                Butter Maggi                                        57
#                           Bun Maska                                           52
#                                                                             ...
# Classic Margherita Pizza  Cold Coffee - Frappe                                 1
#                           Classic Nachos                                       1
# Classic Hot Coffee        Vada Pav + Chai / Adrak Elaichi Chai / Vada Pav      1
#                           Vada Pav + Chai / Adrak Chai / Vada Pav              1
# Cold Coffee - Frappe      Water (500 ml)                                       1
# Length: 2412, dtype: int64
